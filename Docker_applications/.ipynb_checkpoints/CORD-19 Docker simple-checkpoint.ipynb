# %%
import matplotlib.pyplot as plt
import numpy as np
from random import random
import time
import pickle

# %%
from vespa.package import Document, Field

document = Document(
    fields=[
        Field(name = "id", type = "string", indexing = ["attribute", "summary"]),
        Field(name = "title", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "abstract", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "body", type = "string", indexing = ["index", "summary"], index = "enable-bm25"),
        Field(name = "title_embedding", type = "tensor<float>(x[768]) ", indexing = ["attribute", "summary"])
    ]
)

# %%
from vespa.package import Schema, FieldSet, RankProfile

cord_19_schema = Schema(
    name = "cord_19",
    document = document,
    fieldsets = [FieldSet(name = "default", fields = ["title", "body"])],
    rank_profiles = [RankProfile(name = "default", first_phase = "nativeRank(title, body)"),
                    RankProfile(name = "bm25", first_phase = "bm25(title) + bm25(body)")]
)

# %%
from vespa.package import ApplicationPackage

app_package = ApplicationPackage(name = "cord_19", schema=cord_19_schema)

# %%
from vespa.package import VespaCloud

            #C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP
path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"
file = "andre.olaisen.tmartins-ntnu.pem"


# App name in Cloud
app_name = "andre-cord-19"
vespa_cloud = VespaCloud(
    tenant="tmartins-ntnu",
    application=app_name,
    key_location=path_key + file,
    application_package=app_package
)

# %%
name = "cord_19_application_simple"
path = path_key + name
print(path)
# Out:
# C:\Users\User\OneDrive - NTNU\NTNU\Prosjekt oppgave NLP\Cloud_test\cord_19_application_simple

# %%
name = "cord_19_application_simple"

path_key = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\Cloud_test\\"


app = vespa_cloud.deploy(
    instance='andre-olaisen',
    disk_folder=path_key
)
# Out:
# Deployment started in run 2 of dev-aws-us-east-1c for tmartins-ntnu.andre-cord-19.andre-olaisen. This may take about 15 minutes the first time.
# INFO    [10:52:00]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:52:09]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:52:30]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:52:39]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:53:00]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:53:09]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:53:30]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:53:39]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:54:00]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:54:10]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:54:30]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:54:40]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:55:00]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:55:09]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:55:30]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:55:39]  Waiting for provisioned web certificate — new application, or old one has expired
# INFO    [10:56:00]  Deploying platform version 7.318.21 and application version unknown ...
# INFO    [10:56:20]  Deployment successful.
# INFO    [10:56:20]  Session 5103 for tenant 'tmartins-ntnu' prepared and activated.
# INFO    [10:56:26]  ######## Details for all nodes ########
# INFO    [10:56:51]  h5255b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:56:51]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:56:51]  --- container on port 4080 has not started
# INFO    [10:56:51]  h5256i.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:56:51]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:56:51]  --- searchnode on port 19107 has not started
# INFO    [10:56:51]  --- container-clustercontroller on port 19050 has not started
# INFO    [10:56:51]  --- storagenode on port 19102 has not started
# INFO    [10:56:51]  --- distributor on port 19111 has not started
# INFO    [10:56:51]  h5252b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:56:51]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:56:51]  --- logserver-container on port 4080 has not started
# INFO    [10:57:00]  h5255b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:57:00]  h5256i.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:57:00]  h5252b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:57:30]  h5255b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:30]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:57:30]  h5256i.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:30]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:57:30]  h5252b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:57:30]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:58:00]  h5255b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:58:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:58:00]  h5256i.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:58:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:58:00]  h5252b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:58:00]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:58:30]  h5252b.dev.aws-us-east-1c.vespa-external.aws.oath.cloud: expected to be UP
# INFO    [10:58:30]  --- platform vespa/centos-tenant:7.318.21 <-- :
# INFO    [10:59:00]  Found endpoints:
# INFO    [10:59:00]  - dev.aws-us-east-1c
# INFO    [10:59:00]   |-- https://cord-19-container.andre-olaisen.andre-cord-19.tmartins-ntnu.aws-us-east-1c.dev.public.vespa.oath.cloud/ (cluster 'cord_19_container')
# INFO    [10:59:02]  Installation succeeded!

# %%
from pandas import read_csv

path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"
docs = read_csv(path + "crod_19_only_rel.csv")
docs.shape
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (37279, 21)

# %%
docs.head()
# Out:
#    Unnamed: 0  cord_uid                                       sha source_x  \
# 0           3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 1           5  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 2           7  8zchiykl  5806726a24dc91de3954001effbdffd7a82d54e2      PMC
# 3          10  5tkvsudh  9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9      PMC
# 4          12  tvxpckxo  d09b79026117ec9faebba46a8d13aa9b23ec751e      PMC
#
#                                                title  \
# 0               Role of endothelin-1 in lung disease
# 1  Sequence requirements for RNA strand transfer ...
# 2  The 21st International Symposium on Intensive ...
# 3  Conservation of polyamine regulation by transl...
# 4  A Method to Identify p62's UBA Domain Interact...
#
#                         doi      pmcid   pubmed_id   license  \
# 0              10.1186/rr44   PMC59574  11686871.0     no-cc
# 1  10.1093/emboj/20.24.7220  PMC125340  11742998.0  green-oa
# 2            10.1186/cc1013  PMC137274  11353930.0     no-cc
# 3   10.1093/emboj/19.8.1907  PMC302018  10775274.0     no-cc
# 4             10.1251/bpo66  PMC302190  14702098.0     no-cc
#
#                                             abstract  ...  \
# 0  Endothelin-1 (ET-1) is a 21 amino acid peptide...  ...
# 1  Nidovirus subgenomic mRNAs contain a leader se...  ...
# 2  The 21st International Symposium on Intensive ...  ...
# 3  Regulation of ornithine decarboxylase in verte...  ...
# 4  The UBA domain is a conserved sequence motif a...  ...
#
#                                              authors             journal  \
# 0  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M          Respir Res
# 1  Pasternak, Alexander O.; van den Born, Erwin; ...    The EMBO Journal
# 2                      Ball, Jonathan; Venn, Richard           Crit Care
# 3  Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami,...              EMBO J
# 4  Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...  Biol Proced Online
#
#   mag_id  who_covidence_id arxiv_id  \
# 0    NaN               NaN      NaN
# 1    NaN               NaN      NaN
# 2    NaN               NaN      NaN
# 3    NaN               NaN      NaN
# 4    NaN               NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 1  document_parses/pdf_json/b2897e1277f56641193a6...
# 2  document_parses/pdf_json/5806726a24dc91de39540...
# 3  document_parses/pdf_json/9d4e3e8eb092d5ed282d0...
# 4  document_parses/pdf_json/d09b79026117ec9faebba...
#
#                                 pmc_json_files  \
# 0   document_parses/pmc_json/PMC59574.xml.json
# 1  document_parses/pmc_json/PMC125340.xml.json
# 2  document_parses/pmc_json/PMC137274.xml.json
# 3  document_parses/pmc_json/PMC302018.xml.json
# 4  document_parses/pmc_json/PMC302190.xml.json
#
#                                                  url s2_id  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...   NaN
# 1  http://europepmc.org/articles/pmc125340?pdf=re...   NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...   NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...   NaN
#
#                                            body_text
# 0  from xenopus laevis [16] . eta receptors in no...
# 1  the genetic information of rna viruses is orga...
# 2  this year's symposium was dominated by the res...
# 3  the ef®ciency of +1 ribosomal frameshifting at...
# 4  p62 is a novel cellular protein which was init...
#
# [5 rows x 21 columns]

# %%
start = time.time()
m = start
i = 0
for idx, row in docs.iterrows():
    if True:
        if (i % 1000 == 0):
            # Each loop about 10 min or 600 s
            print(i," : " ,idx)
            print("Time:", round(time.time() - m,1))
            m = time.time()
        i += 1
        #print(len(row["title"]), end = "  ")
        response = app.feed_data_point(
            schema = "cord_19",
            data_id = str(row["cord_uid"]),
            fields = {
                "id": str(row["cord_uid"]),
                "title": str(row["title"]),
                "abstract": str(row["abstract"]),
                "body": str(row["body_text"])
            }
        )
# Out:
# 0  :  0
# Time: 0.0
# 1000  :  1000
# Time: 1219.0
# 2000  :  2000
# Time: 1144.2
# 3000  :  3000
# Time: 913.0
# 4000  :  4000
# Time: 1287.3
# 5000  :  5000
# Time: 542.9
# 6000  :  6000
# Time: 505.2
# 7000  :  7000
# Time: 564.4
# 8000  :  8000
# Time: 530.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f57611d8676f> in <module>
#      18                 "title": str(row["title"]),
#      19                 "abstract": str(row["abstract"]),
# ---> 20                 "body": str(row["body_text"])
#      21             }
#      22         )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\vespa\application.py in feed_data_point(self, schema, data_id, fields)
#     126         )
#     127         vespa_format = {"fields": fields}
# --> 128         response = post(end_point, json=vespa_format, cert=self.cert)
#     129         return response
#     130
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
def feed_datapoint(row,i):
    #embedding_title = np.zeros(768)
    #embedding_body = np.zeros(768)
    
    #if type(row["title"]) != float:
        #embedding_title =  model.encode(row["title"].lower()).tolist()
    #else:
    #    embedding_title = [0 for _ in range(768)]
    
    #if type(row["body"]) != float:
    #    embedding_body =  model.encode(row["body"].lower()).tolist()
    #else:
    #    embedding_body = [0 for _ in range(768)]
    #print(len(row["title"]), end = "  ")
    
    print(i)
    response = app.feed_data_point(
        schema = "cord_19",
        data_id = str(row["cord_uid"]),
        fields = {
            "id": str(row["cord_uid"]),
            "title": str(row["title"]),
            "abstract": str(row["abstract"]),
            "body": str(row["body_text"])
        }
    )
    return(i)

# %%
import multiprocessing
from joblib import Parallel, delayed

# %%
s = time.time()
a = Parallel(n_jobs=2)(delayed(feed_datapoint)(row, idx) for idx, row in docs.iterrows())
time.time() - s
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\loky\backend\queues.py", line 153, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 271, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 264, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 563, in dump
#     return Pickler.dump(self, obj)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 437, in dump
#     self.save(obj)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 638, in save_reduce
#     save(args)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 786, in save_tuple
#     save(element)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 816, in save_list
#     self._batch_appends(obj)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 843, in _batch_appends
#     save(tmp[0])
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 745, in save_function
#     *self._dynamic_function_reduce(obj), obj=obj
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 687, in _save_reduce_pickle5
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 771, in save_tuple
#     save(element)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 887, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 549, in save
#     self.save_reduce(obj=obj, *rv)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 662, in save_reduce
#     save(state)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 504, in save
#     f(self, obj) # Call unbound method with explicit self
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 856, in save_dict
#     self._batch_setitems(obj.items())
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 882, in _batch_setitems
#     save(v)
#   File "C:\Users\User\AppData\Local\Continuum\anaconda3\lib\pickle.py", line 524, in save
#     rv = reduce(self.proto)
#   File "stringsource", line 2, in zmq.backend.cython.context.Context.__reduce_cython__
# TypeError: no default __reduce__ due to non-trivial __cinit__
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-27-31b4076c8ca5> in <module>
#       1 s = time.time()
# ----> 2 a = Parallel(n_jobs=2)(delayed(feed_datapoint)(row, idx) for idx, row in docs.iterrows())
#       3 time.time() - s
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~\AppData\Local\Continuum\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# ~\AppData\Local\Continuum\anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
labeled_data = [
    {
        'query_id': 1,
        'query': 'coronavirus origin',
        'relevant_docs': [{'id': '005b2j4b', 'score': 2}, {'id': '00fmeepz', 'score': 1}]
    },
    {
        'query_id': 2,
        'query': 'coronavirus response to weather changes',
        'relevant_docs': [{'id': '01goni72', 'score': 2}, {'id': '03h85lvy', 'score': 2}]
    }
]

# %% [markdown]
# ### Loading labeled data

# %%
path = "C:\\Users\\User\\OneDrive - NTNU\\NTNU\\Prosjekt oppgave NLP\\dataset\\CORD-19\\"

labeled_data = []
with open(path + "labeled_data_cord_19.txt", "rb") as fp:   # Unpickling
    labeled_data = pickle.load(fp)

# %%
from vespa.query import Query, OR, AND, WeakAnd, ANN, RankProfile as Ranking


results = app.query(
    query="Where is my app",
    query_model = Query(
        match_phase=AND(),
        rank_profile=Ranking(name="default")
    ),
    hits = 10
)

# %%
len(results.hits)
for result in results.hits:
    print(result["id"], "  ", result["fields"]["title"])

# %% [markdown]
# ## Evaluating app

# %%
from vespa.evaluation import MatchRatio, Recall, ReciprocalRank, NormalizedDiscountedCumulativeGain

eval_metrics = [
    MatchRatio(),
    Recall(at=10),
    ReciprocalRank(at=10),
    NormalizedDiscountedCumulativeGain(at=10)
]

# %%
model = Query(match_phase=OR(),
      rank_profile=Ranking(name="default")
    )

# %%
bm25_evaluation = app.evaluate(
        labeled_data = labeled_data,
        eval_metrics = eval_metrics,
        query_model = model,
        id_field = "id",
        hits = 10
    )

# %%
bm25_evaluation
# Out:
#    query_id  match_ratio_retrieved_docs  match_ratio_docs_available  \
# 0         1                        2562                        7879
# 1         2                        4762                        7879
# 2         3                        3164                        7879
# 3         4                        5667                        7879
# 4         5                        6493                        7879
# 5         6                        4001                        7879
# 6         7                        4955                        7879
# 7         8                        4053                        7879
# 8         9                        5621                        7879
# 9        10                        3595                        7879
# 10       11                        2850                        7879
# 11       12                        2185                        7879
# 12       13                        3980                        7879
# 13       14                        2998                        7879
# 14       15                        3113                        7879
# 15       16                        4624                        7879
# 16       17                        3566                        7879
# 17       18                        3343                        7879
# 18       19                        3146                        7879
# 19       20                        5672                        7879
# 20       21                        2943                        7879
# 21       22                        3436                        7879
# 22       23                        2256                        7879
# 23       24                        2341                        7879
# 24       25                        2215                        7879
# 25       26                        3694                        7879
# 26       27                        2360                        7879
# 27       28                        2030                        7879
# 28       29                        2929                        7879
# 29       30                        1977                        7879
# 30       31                        5675                        7879
# 31       32                        2390                        7879
# 32       33                        3060                        7879
# 33       34                        2504                        7879
# 34       35                        3145                        7879
# 35       36                        2318                        7879
# 36       37                        2987                        7879
# 37       38                        4117                        7879
# 38       39                        2931                        7879
# 39       40                        2563                        7879
# 40       41                        5931                        7879
# 41       42                        6013                        7879
# 42       43                        3291                        7879
# 43       44                        6225                        7879
# 44       45                        3958                        7879
# 45       46                        2059                        7879
# 46       47                        5975                        7879
# 47       48                        2433                        7879
# 48       49                        3893                        7879
# 49       50                        3036                        7879
#
#     match_ratio_value  recall_10_value  reciprocal_rank_10_value  \
# 0            0.325168         0.001214                  1.000000
# 1            0.604391         0.006216                  1.000000
# 2            0.401574         0.001777                  1.000000
# 3            0.719254         0.001622                  0.250000
# 4            0.824089         0.001179                  0.142857
# 5            0.507806         0.003111                  1.000000
# 6            0.628887         0.004342                  1.000000
# 7            0.514405         0.000535                  0.333333
# 8            0.713415         0.005409                  1.000000
# 9            0.456276         0.004382                  0.500000
# 10           0.361721         0.001647                  0.200000
# 11           0.277319         0.001230                  0.500000
# 12           0.505140         0.001585                  0.333333
# 13           0.380505         0.003858                  1.000000
# 14           0.395101         0.002524                  0.500000
# 15           0.586877         0.003049                  1.000000
# 16           0.452596         0.006652                  1.000000
# 17           0.424292         0.003019                  1.000000
# 18           0.399289         0.004030                  1.000000
# 19           0.719888         0.004862                  1.000000
# 20           0.373525         0.001250                  1.000000
# 21           0.436096         0.000755                  1.000000
# 22           0.286331         0.000000                  0.000000
# 23           0.297119         0.003205                  1.000000
# 24           0.281127         0.003774                  1.000000
# 25           0.468841         0.001744                  0.333333
# 26           0.299530         0.000677                  1.000000
# 27           0.257647         0.003626                  1.000000
# 28           0.371748         0.004029                  1.000000
# 29           0.250920         0.001932                  1.000000
# 30           0.720269         0.001764                  1.000000
# 31           0.303338         0.000637                  0.125000
# 32           0.388374         0.007874                  1.000000
# 33           0.317807         0.001086                  0.333333
# 34           0.399162         0.002206                  0.500000
# 35           0.294200         0.004055                  1.000000
# 36           0.379109         0.005673                  1.000000
# 37           0.522528         0.004167                  1.000000
# 38           0.372002         0.006329                  1.000000
# 39           0.325295         0.000813                  1.000000
# 40           0.752761         0.002876                  1.000000
# 41           0.763168         0.010403                  1.000000
# 42           0.417693         0.003417                  0.500000
# 43           0.790075         0.005654                  1.000000
# 44           0.502348         0.006832                  1.000000
# 45           0.261328         0.000000                  0.000000
# 46           0.758345         0.003759                  1.000000
# 47           0.308796         0.005355                  1.000000
# 48           0.494098         0.001830                  0.111111
# 49           0.385328         0.008999                  1.000000
#
#     ndcg_10_ideal_dcg  ndcg_10_dcg  ndcg_10_value
# 0            0.000000     0.000000       0.000000
# 1            0.000000     0.000000       0.000000
# 2            1.630930     1.301030       0.797723
# 3            1.000000     0.333333       0.333333
# 4            1.000000     0.333333       0.333333
# 5            3.130930     2.630930       0.840303
# 6            2.630930     2.289065       0.870059
# 7            0.000000     0.000000       0.000000
# 8            0.000000     0.000000       0.000000
# 9            3.261860     1.314474       0.402983
# 10           0.000000     0.000000       0.000000
# 11           0.000000     0.000000       0.000000
# 12           1.000000     0.289065       0.289065
# 13           3.761860     2.928526       0.778478
# 14           1.630930     0.801030       0.491149
# 15           1.630930     0.815465       0.500000
# 16           4.692536     3.982132       0.848610
# 17           2.630930     1.107039       0.420779
# 18           0.000000     0.000000       0.000000
# 19           4.192536     3.653804       0.871502
# 20           0.000000     0.000000       0.000000
# 21           0.000000     0.000000       0.000000
# 22           0.000000     0.000000       0.000000
# 23           3.261860     3.261860       1.000000
# 24           0.000000     0.000000       0.000000
# 25           2.630930     1.386853       0.527134
# 26           1.000000     1.000000       1.000000
# 27           4.692536     4.099267       0.873572
# 28           3.761860     3.692536       0.981572
# 29           1.000000     1.000000       1.000000
# 30           2.000000     1.261860       0.630930
# 31           0.000000     0.000000       0.000000
# 32           3.130930     1.992283       0.636323
# 33           2.000000     0.773706       0.386853
# 34           1.000000     0.430677       0.430677
# 35           5.123213     4.789879       0.934937
# 36           3.761860     3.045748       0.809639
# 37           4.192536     2.400297       0.572517
# 38           5.435596     5.083661       0.935254
# 39           2.000000     2.000000       1.000000
# 40           3.761860     3.430677       0.911963
# 41           5.510065     5.030586       0.912981
# 42           1.000000     0.356207       0.356207
# 43           5.079389     4.230252       0.832827
# 44           4.692536     4.071302       0.867612
# 45           0.000000     0.000000       0.000000
# 46           2.000000     0.773706       0.386853
# 47           3.561606     2.589197       0.726974
# 48           0.000000     0.000000       0.000000
# 49           2.630930     1.692536       0.643322

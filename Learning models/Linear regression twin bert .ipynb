# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import pickle
import torch.nn as nn
from torch.autograd import Variable
import random

# %%
#TODO add split 1-35 train and 36-50 test

# %% [markdown]
# ## Create dataset

# %%
# loading relevancy data

path = 'C:/Users/User/OneDrive - NTNU/NTNU/Prosjekt oppgave NLP/dataset/CORD-19/'
file = 'relevance_data.csv'

label_data = pd.read_csv(path + file)
label_data.head()
# Out:
#    Unnamed: 0  topic_id  round_id  cord_uid  relevancy
# 0           0         1       4.5  005b2j4b          2
# 1           1         1       4.0  00fmeepz          1
# 2           2         1       0.5  010vptx3          2
# 3           3         1       2.5  0194oljo          1
# 4           4         1       4.0  021q9884          1

# %%
# loading topics data

path = 'C:/Users/User/OneDrive - NTNU/NTNU/Prosjekt oppgave NLP/dataset/CORD-19/'
file = 'topics.csv'

topics = pd.read_csv(path + file)
topics.head()
# Out:
#    query_id                                    query  \
# 0         1                       coronavirus origin
# 1         2  coronavirus response to weather changes
# 2         3                     coronavirus immunity
# 3         4   how do people die from the coronavirus
# 4         5                animal models of COVID-19
#
#                                             question  \
# 0                     what is the origin of COVID-19
# 1  how does the coronavirus respond to changes in...
# 2  will SARS-CoV2 infected people develop immunit...
# 3                   what causes death from Covid-19?
# 4  what drugs have been active against SARS-CoV o...
#
#                                            narrative
# 0  seeking range of information about the SARS-Co...
# 1  seeking range of information about the SARS-Co...
# 2  seeking studies of immunity developed due to i...
# 3  Studies looking at mechanisms of death from Co...
# 4  Papers that describe the results  of testing d...

# %%
len(label_data)
# Out:
# 69318

# %%
train_topics = [i+1 for i in range(35)]
test_topics = [i+1 for i in range(35,50)]

# %%
# available models: ['bert-base-uncased', "allenai/scibert_scivocab_uncased", "gsarti/covidbert-nli"]

def normalize_tensor(tensor):
    tensor_normed = []
    norm = torch.norm(tensor)
    if norm>0:
        tensor_normed = tensor/norm
    else:
        tensor_normed = tensor
    return tensor_normed

def get_tesors(row, topic_field, doc_field, model):
    topic_path = "C:/Users/User/Documents/NTNU/NLP/CORD-19/topic_embeddings/"
    doc_path = "C:/Users/User/Documents/NTNU/NLP/CORD-19/Embeddings/786/"
    doc_id = row["cord_uid"]
    topic_id = row["topic_id"]
    topic_tensor = []
    doc_tensor = []
    
    doc_embedding_file = doc_path + doc_id + ".txt"
    try:
        with open(doc_embedding_file, "rb") as fp:   # Unpickling
            doc_embedding = pickle.load(fp)
    except:
        return [[0]], [[0]]
        
    doc_tensor = doc_embedding["models"][model][doc_field]
            
    topic_embedding_file = topic_path + str(topic_id) + ".txt"
    with open(topic_embedding_file, "rb") as fp:   # Unpickling
        topic_embedding = pickle.load(fp)
        
    topic_tensor =  topic_embedding["models"][model][topic_field]
    
    topic_tensor = normalize_tensor(topic_tensor)
    doc_tensor = normalize_tensor(doc_tensor)
    
    return topic_tensor, doc_tensor

# %%
def join_tensors(tensor_a,tensor_b):
    n = len(tensor_a)
    m = len(tensor_b)
    c = torch.empty(n + m)
    c[0:n] = tensor_a
    c[n:(n+m)] = tensor_b
    return c

# %%
def isNaN(num):
    return num != num

# %%
def load_data(n_datapoints, doc_field, query_field, encoder_model):
    
    topic_dataset = torch.empty(n_datapoints, 768)
    document_dataset = torch.empty(n_datapoints, 768)
    rel = torch.empty(n_datapoints)
    
    miss = 0
    i = 0
    for idx, row in label_data.iterrows():
        if idx < num:
            a, b = get_tesors(row, query_field, doc_field, encoder_model)
            if len(a[0]) != 1:
              
                topic_dataset[i] = a[0]
                document_dataset[i] = b[0]
        
                rel[i] = row["relevancy"]
                i += 1
            else:
                miss += 1
            if(idx % 5000) == 0:
                print(idx)
    
    document_dataset = document_dataset[0:(num-miss)]
    topic_dataset = topic_dataset[0:(num-miss)]
    rel = rel[0:(num-miss)]
    
    return topic_dataset, document_dataset, rel, miss

# %%
def load_data_top_id(type_d, doc_field, query_field, encoder_model):
    
    label_dat_top = []
    if type_d == "train":
        label_dat_top = label_data[label_data["topic_id"] < 36]
    else:
        label_dat_top = label_data[label_data["topic_id"] > 35]
        
    n_datapoints = len(label_dat_top["topic_id"])
    print("Number of datapoints for ",type_d," ",n_datapoints)
    topic_dataset = torch.empty(n_datapoints, 768)
    document_dataset = torch.empty(n_datapoints, 768)
    rel = torch.empty(n_datapoints)
    
    miss = 0
    i = 0
    for idx, row in label_dat_top.iterrows():
        a, b = get_tesors(row, query_field, doc_field, encoder_model)
        if len(a[0]) != 1:

            topic_dataset[i] = a[0]
            document_dataset[i] = b[0]

            rel[i] = row["relevancy"]
            i += 1
        else:
            miss += 1
        if(idx % 5000) == 0:
            print(idx)
    
    document_dataset = document_dataset[0:(num-miss)]
    topic_dataset = topic_dataset[0:(num-miss)]
    rel = rel[0:(num-miss)]
    
    return topic_dataset, document_dataset, rel, miss

# %%
def join_datasets(doc, query, relevancy, num_class, type_join):
    relevancy_temp = torch.empty(len(relevancy))
    for i , rel in enumerate(relevancy):
        r = rel
        if num_class == 2:
            if rel > 0.01:
                r = 1
        relevancy_temp[i] = r

    n = len(relevancy_temp)
    X_dataset = []
    
    if type_join == "multi":
        X_dataset = torch.empty(n, 768)
        for i in range(n):
            X_dataset[i] = doc[i]*query[i]
    elif type_join == "abs":
        X_dataset = torch.empty(n, 768)
        for i in range(n):
            X_dataset[i] = torch.abs((doc[i] - query[i]))
    else: 
        X_dataset = torch.empty(n, 768*2)
        for i in range(n):
            X_dataset[i] = join_tensors(doc[i],query[i])
    joint_dataset = torch.cat((X_dataset, relevancy_temp.unsqueeze(1)), 1)
    return joint_dataset

# %%
#loading 
num = 40000 # max: 69318

available_models = ['bert-base-uncased', "allenai/scibert_scivocab_uncased", "gsarti/covidbert-nli"]
bert_model = available_models[2]
query_field = "query"
doc_field = "title"

# %%
label_dat_top = label_data[label_data["topic_id"] < 35]
label_dat_top.head()
# Out:
#    Unnamed: 0  topic_id  round_id  cord_uid  relevancy
# 0           0         1       4.5  005b2j4b          2
# 1           1         1       4.0  00fmeepz          1
# 2           2         1       0.5  010vptx3          2
# 3           3         1       2.5  0194oljo          1
# 4           4         1       4.0  021q9884          1

# %%
topic_dat_train, doc_dat_train, rel_dat_train, miss_train  = load_data_top_id("train", doc_field, query_field, bert_model)
topic_dat_test, doc_dat_test, rel_dat_test, miss_test  = load_data_top_id("test", doc_field, query_field, bert_model)
# Out:
# Number of datapoints for  train   52865
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# Number of datapoints for  test   16453
# 55000
# 60000
# 65000

# %%
# Possible types: [multi, sum, abs]
joining_type = "sum"

# Model Hyper Parameters 
input_size = 768
if joining_type == "sum":
    input_size = 768*2

# Can use 2 or 3 classes
num_classes = 2

# Training set sub or full
training = "sub"

# %%
print(list(topic_dat_train.size()))
print(list(doc_dat_train.size()))
print(list(rel_dat_train.size()))
print(list(topic_dat_test.size()))
print(list(doc_dat_test.size()))
print(list(rel_dat_test.size()))
# Out:
# [37935, 768]
# [37935, 768]
# [37935]
# [16453, 768]
# [16453, 768]
# [16453]

# %%
print(rel_dat_train.int().tolist().count(0)/len(rel_dat_train))
print(rel_dat_train.int().tolist().count(1)/len(rel_dat_train))
if num_classes == 3:
    print(rel_dat_train.int().tolist().count(2)/len(rel_dat_train))

print(rel_dat_test.int().tolist().count(0)/len(rel_dat_test))
print(rel_dat_test.int().tolist().count(1)/len(rel_dat_test))
if num_classes == 3:
    print(rel_dat_test.int().tolist().count(2)/len(rel_dat_test))
# Out:
# 0.6459470146302887
# 0.1605904837221563
# 0.5478636114994226
# 0.1651978362608643

# %%
train_data = join_datasets(topic_dat_train, doc_dat_train, rel_dat_train, num_classes, joining_type)
test_data = join_datasets(topic_dat_test, doc_dat_test, rel_dat_test, num_classes, joining_type)

# %%
print(list(train_data.size()))
print(list(test_data.size()))
print(train_data[:,input_size])
# Out:
# [37935, 1537]
# [16453, 1537]
# tensor([1., 1., 1.,  ..., 1., 1., 0.], grad_fn=<SelectBackward>)

# %%
y = train_data[:,input_size]
X = train_data[:,0:(input_size)]

if training == "full":
    y = torch.cat((train_data[:,input_size],test_data[:,input_size]))
    X = torch.cat((train_data[:,0:(input_size)] ,test_data[:,0:(input_size)] ))
print(list(X.size()))
print(list(y.size()))
# Out:
# [37935, 1536]
# [37935]

# %% [markdown]
# model
#
# $$
#     \hat{\beta} = (X^TX)^{-1}X^Ty
# $$
#
# Fitting the model

# %%
l = X.t()
print(list(l.size()))
print(list(X.size()))
l = torch.mm(l, X)
print(list(l.size()))
l = torch.inverse(l)
print(list(l.size()))
l = torch.mm(l,X.t())
print(list(l.size()))
print(list(y.t().size()))
beta_hat = torch.mv(l,y)
print(list(beta_hat.size()))
# Out:
# [1536, 37935]
# [37935, 1536]
# [1536, 1536]
# [1536, 1536]
# [1536, 37935]
# [37935]
# [1536]

# %%
print(beta_hat.tolist())
# Out:
# [66.3646011352539, -326.229736328125, 20.389965057373047, 11.312566757202148, -22.073688507080078, -67.2509536743164, -153.6298065185547, -31.917892456054688, 97.87052917480469, -42.63251495361328, -131.0890350341797, 229.00135803222656, -16.407367706298828, 189.55165100097656, 44.275413513183594, -46.34434509277344, 74.43368530273438, 15.36457347869873, 195.88197326660156, -109.59808349609375, -56.982078552246094, -11.172971725463867, 123.27405548095703, -29.518001556396484, 110.04669952392578, -11.358591079711914, -158.27499389648438, -73.31246948242188, 28.392011642456055, -105.54995727539062, 20.60175323486328, -114.75776672363281, 72.71161651611328, 262.6357116699219, -45.177547454833984, 86.02098083496094, 126.85135650634766, -33.23942947387695, 236.66311645507812, 346.64306640625, -9.280149459838867, -110.97840881347656, -28.793489456176758, 56.776248931884766, -28.690860748291016, 117.82454681396484, 7.552044868469238, 150.72189331054688, 7.738461017608643, 4.238080024719238, 29.636728286743164, 73.0013198852539, -204.9547882080078, 111.59815216064453, -51.82143783569336, 73.38473510742188, 21.176952362060547, 276.2948913574219, -83.39534759521484, -227.25418090820312, -27.94535255432129, 11.586639404296875, -159.91055297851562, 65.95948028564453, 52.86945724487305, -44.762664794921875, -363.6650695800781, -54.58287811279297, 52.948448181152344, -82.41886901855469, 115.85054016113281, 388.15081787109375, -12.772119522094727, 4.87673807144165, -23.778579711914062, -102.59523010253906, 9.954713821411133, -60.551395416259766, -146.41261291503906, -12.439579010009766, -28.689239501953125, -34.24938201904297, 48.99441909790039, -10.187318801879883, 87.82501220703125, 8.817160606384277, 60.14669418334961, 64.02147674560547, -50.71253967285156, 107.03556823730469, -70.47142791748047, -98.07813262939453, 85.82049560546875, -107.51081085205078, 78.05699157714844, -103.37848663330078, 89.66088104248047, 16.31436538696289, 44.5831184387207, -249.57005310058594, -80.052001953125, 611.0797729492188, 95.56964111328125, -30.81290054321289, 53.00119400024414, 157.92892456054688, -24.549957275390625, 211.04502868652344, -46.088111877441406, 87.90227508544922, 149.95159912109375, 25.999521255493164, -142.25241088867188, 28.0312442779541, -62.813941955566406, 273.10516357421875, -0.41090846061706543, 37.51816940307617, -14.011077880859375, 62.09304428100586, -149.92337036132812, -193.7947540283203, -46.33005905151367, -127.57379913330078, 145.89932250976562, -44.77552032470703, 84.71391296386719, 2.341012477874756, 76.94979858398438, -382.0299987792969, 84.12068176269531, 103.02308654785156, -21.90874481201172, -22.394163131713867, 36.93973159790039, 16.27821922302246, -259.78668212890625, -36.66355895996094, 360.7085876464844, 54.919281005859375, -53.39414978027344, 24.949363708496094, 35.49103546142578, -42.57798385620117, 298.18267822265625, -293.5562438964844, 5.700457572937012, 18.15389633178711, 70.48995208740234, -17.706636428833008, 216.15208435058594, -109.60470581054688, -10.11752986907959, 56.067604064941406, -55.09184646606445, -39.97871398925781, -10.84852409362793, -11.579118728637695, 8.771221160888672, 20.27540397644043, -32.33821105957031, -57.9312744140625, 25.972126007080078, 93.2495346069336, -21.175439834594727, -140.04490661621094, 74.14087677001953, 55.71244812011719, 52.160797119140625, 55.606388092041016, 178.5240020751953, 134.39341735839844, -25.50551414489746, -25.267168045043945, 87.40017700195312, -61.676666259765625, -15.401528358459473, -72.69303131103516, -214.10861206054688, -25.1209716796875, 164.8716278076172, -43.60165786743164, 11.480198860168457, -28.507347106933594, -368.1020812988281, -265.82049560546875, -30.263525009155273, 45.10054016113281, 60.40454864501953, 55.77592086791992, 44.421722412109375, 89.39140319824219, -31.19552993774414, -98.42145538330078, 116.81468200683594, 97.49555206298828, -2.086085557937622, 52.3345947265625, -181.40017700195312, 181.218994140625, -194.350830078125, -38.4 ...

# %%
y_test = test_data[:,input_size]
X_test = test_data[:,0:(input_size)]

# %%
# Prediction from the model
y_hat =  torch.mv(X_test,beta_hat)

# %%
for i in range(100):
    print((y_hat[i] - y_test[i]))
    print((y_hat[i] , y_test[i]))
# Out:
# tensor(26.7580, grad_fn=<SubBackward0>)
# (tensor(27.7580, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0455, grad_fn=<SubBackward0>)
# (tensor(28.0455, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2414, grad_fn=<SubBackward0>)
# (tensor(28.2414, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9381, grad_fn=<SubBackward0>)
# (tensor(27.9381, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9843, grad_fn=<SubBackward0>)
# (tensor(27.9843, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.8145, grad_fn=<SubBackward0>)
# (tensor(27.8145, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.9706, grad_fn=<SubBackward0>)
# (tensor(27.9706, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8743, grad_fn=<SubBackward0>)
# (tensor(27.8743, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9298, grad_fn=<SubBackward0>)
# (tensor(27.9298, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.8137, grad_fn=<SubBackward0>)
# (tensor(27.8137, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8769, grad_fn=<SubBackward0>)
# (tensor(27.8769, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.2741, grad_fn=<SubBackward0>)
# (tensor(28.2741, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.9000, grad_fn=<SubBackward0>)
# (tensor(27.9000, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8063, grad_fn=<SubBackward0>)
# (tensor(27.8063, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.0712, grad_fn=<SubBackward0>)
# (tensor(28.0712, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.7783, grad_fn=<SubBackward0>)
# (tensor(27.7783, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.8708, grad_fn=<SubBackward0>)
# (tensor(27.8708, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.0566, grad_fn=<SubBackward0>)
# (tensor(28.0566, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.1535, grad_fn=<SubBackward0>)
# (tensor(28.1535, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2735, grad_fn=<SubBackward0>)
# (tensor(28.2735, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9408, grad_fn=<SubBackward0>)
# (tensor(27.9408, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.0675, grad_fn=<SubBackward0>)
# (tensor(28.0675, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0168, grad_fn=<SubBackward0>)
# (tensor(28.0168, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9389, grad_fn=<SubBackward0>)
# (tensor(27.9389, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9715, grad_fn=<SubBackward0>)
# (tensor(27.9715, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8719, grad_fn=<SubBackward0>)
# (tensor(27.8719, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8069, grad_fn=<SubBackward0>)
# (tensor(27.8069, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.3203, grad_fn=<SubBackward0>)
# (tensor(28.3203, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.8625, grad_fn=<SubBackward0>)
# (tensor(27.8625, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.7907, grad_fn=<SubBackward0>)
# (tensor(27.7907, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.9516, grad_fn=<SubBackward0>)
# (tensor(27.9516, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.8579, grad_fn=<SubBackward0>)
# (tensor(27.8579, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.7745, grad_fn=<SubBackward0>)
# (tensor(27.7745, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.7940, grad_fn=<SubBackward0>)
# (tensor(27.7940, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.0715, grad_fn=<SubBackward0>)
# (tensor(28.0715, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.1920, grad_fn=<SubBackward0>)
# (tensor(28.1920, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.1019, grad_fn=<SubBackward0>)
# (tensor(28.1019, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.8821, grad_fn=<SubBackward0>)
# (tensor(27.8821, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.6832, grad_fn=<SubBackward0>)
# (tensor(27.6832, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.2559, grad_fn=<SubBackward0>)
# (tensor(28.2559, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8768, grad_fn=<SubBackward0>)
# (tensor(27.8768, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8757, grad_fn=<SubBackward0>)
# (tensor(27.8757, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9666, grad_fn=<SubBackward0>)
# (tensor(27.9666, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.9974, grad_fn=<SubBackward0>)
# (tensor(27.9974, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.6767, grad_fn=<SubBackward0>)
# (tensor(27.6767, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.0636, grad_fn=<SubBackward0>)
# (tensor(28.0636, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.1150, grad_fn=<SubBackward0>)
# (tensor(28.1150, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8111, grad_fn=<SubBackward0>)
# (tensor(27.8111, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.7291, grad_fn=<SubBackward0>)
# (tensor(27.7291, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9530, grad_fn=<SubBackward0>)
# (tensor(27.9530, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0994, grad_fn=<SubBackward0>)
# (tensor(28.0994, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2505, grad_fn=<SubBackward0>)
# (tensor(28.2505, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2408, grad_fn=<SubBackward0>)
# (tensor(28.2408, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.1577, grad_fn=<SubBackward0>)
# (tensor(28.1577, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.9737, grad_fn=<SubBackward0>)
# (tensor(27.9737, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.7520, grad_fn=<SubBackward0>)
# (tensor(27.7520, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.7798, grad_fn=<SubBackward0>)
# (tensor(27.7798, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.1139, grad_fn=<SubBackward0>)
# (tensor(28.1139, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8838, grad_fn=<SubBackward0>)
# (tensor(27.8838, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.3206, grad_fn=<SubBackward0>)
# (tensor(28.3206, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9403, grad_fn=<SubBackward0>)
# (tensor(27.9403, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.8916, grad_fn=<SubBackward0>)
# (tensor(27.8916, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8820, grad_fn=<SubBackward0>)
# (tensor(27.8820, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9174, grad_fn=<SubBackward0>)
# (tensor(27.9174, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.9187, grad_fn=<SubBackward0>)
# (tensor(27.9187, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.7986, grad_fn=<SubBackward0>)
# (tensor(27.7986, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2385, grad_fn=<SubBackward0>)
# (tensor(28.2385, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2657, grad_fn=<SubBackward0>)
# (tensor(28.2657, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8865, grad_fn=<SubBackward0>)
# (tensor(27.8865, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8360, grad_fn=<SubBackward0>)
# (tensor(27.8360, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.7641, grad_fn=<SubBackward0>)
# (tensor(27.7641, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9881, grad_fn=<SubBackward0>)
# (tensor(27.9881, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.8159, grad_fn=<SubBackward0>)
# (tensor(27.8159, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.1524, grad_fn=<SubBackward0>)
# (tensor(28.1524, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0090, grad_fn=<SubBackward0>)
# (tensor(28.0090, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.8932, grad_fn=<SubBackward0>)
# (tensor(27.8932, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.5967, grad_fn=<SubBackward0>)
# (tensor(27.5967, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9682, grad_fn=<SubBackward0>)
# (tensor(27.9682, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.4069, grad_fn=<SubBackward0>)
# (tensor(28.4069, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9420, grad_fn=<SubBackward0>)
# (tensor(27.9420, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.9765, grad_fn=<SubBackward0>)
# (tensor(27.9765, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0262, grad_fn=<SubBackward0>)
# (tensor(28.0262, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0898, grad_fn=<SubBackward0>)
# (tensor(28.0898, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2280, grad_fn=<SubBackward0>)
# (tensor(28.2280, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.0997, grad_fn=<SubBackward0>)
# (tensor(28.0997, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.9991, grad_fn=<SubBackward0>)
# (tensor(27.9991, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.0886, grad_fn=<SubBackward0>)
# (tensor(28.0886, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(28.0187, grad_fn=<SubBackward0>)
# (tensor(28.0187, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.6095, grad_fn=<SubBackward0>)
# (tensor(27.6095, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.9192, grad_fn=<SubBackward0>)
# (tensor(27.9192, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(28.0712, grad_fn=<SubBackward0>)
# (tensor(28.0712, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.9990, grad_fn=<SubBackward0>)
# (tensor(27.9990, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.3423, grad_fn=<SubBackward0>)
# (tensor(28.3423, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9555, grad_fn=<SubBackward0>)
# (tensor(27.9555, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.5254, grad_fn=<SubBackward0>)
# (tensor(27.5254, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(27.7295, grad_fn=<SubBackward0>)
# (tensor(27.7295, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))
# tensor(26.8538, grad_fn=<SubBackward0>)
# (tensor(27.8538, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.2188, grad_fn=<SubBackward0>)
# (tensor(28.2188, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(26.9698, grad_fn=<SubBackward0>)
# (tensor(27.9698, grad_fn=<SelectBackward>), tensor(1., grad_fn=<SelectBackward>))
# tensor(27.7656, grad_fn=<SubBackward0>)
# (tensor(27.7656, grad_fn=<SelectBackward>), tensor(0., grad_fn=<SelectBackward>))

# %%
diff = (y_hat - y_test)**2

# %%
import numpy as np
import matplotlib.pyplot as plt

print(diff.detach().numpy(),)

# the histogram of the data
n, bins, patches = plt.hist(diff.detach().numpy(), 50, density=True, facecolor='g', alpha=0.75)

#pltting the results

plt.xlim(0, 10)
plt.ylim(0, 1)

plt.grid(True)
plt.show()
# Out:
# [715.9922  731.45856 742.0915  ...   0.        0.        0.     ]

# %%
import numpy as np
from sklearn import metrics
y_pred = y_hat.detach().numpy()
y =  np.asarray(y_test.detach().numpy(), dtype=int)
fpr, tpr, thresholds = metrics.roc_curve(y, y_pred, pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.587888828120125

# %%
import numpy as np
from sklearn import metrics
y_temp = torch.sum(X_test, 1)
print(list(y_temp.size()))
y_pred = y_temp.detach().numpy()
y =  np.asarray(y_test.detach().numpy(), dtype=int)
fpr, tpr, thresholds = metrics.roc_curve(y, y_pred, pos_label=1)
print(fpr, tpr)
metrics.auc(fpr, tpr)
# Out:
# [16453]
# [0.00000000e+00 1.10913931e-04 3.32741792e-04 ... 9.99889086e-01
#  1.00000000e+00 1.00000000e+00] [0.         0.         0.         ... 0.99946215 0.99946215 1.        ]
# 0.4441700553803085

# %%
print(rel_dat_train.int().tolist().count(0)/len(rel_dat_train))
print(rel_dat_train.int().tolist().count(1)/len(rel_dat_train))
if num_classes == 3:
    print(rel_dat_train.int().tolist().count(2)/len(rel_dat_train))

print(rel_dat_test.int().tolist().count(0)/len(rel_dat_test))
print(rel_dat_test.int().tolist().count(1)/len(rel_dat_test))
if num_classes == 3:
    print(rel_dat_test.int().tolist().count(2)/len(rel_dat_test))
# Out:
# 0.6459470146302887
# 0.1605904837221563
# 0.5478636114994226
# 0.1651978362608643
